# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib as mpl
from sklearn.decomposition import PCA
import yaml
from src.feature_extraction import coarsen_density, scale_density, scale_cell_counts, split_data
from src.scree_and_elbow_plotting import pca_scree_plot, kmeans_elbow_plot

# %% [markdown]
# ## This notebook creates all scree and elbow plots

# %% [markdown]
# # **Dataset 1**

# %%
max_pca_dim = 10
min_pca_dim = 1
max_clusters = 10
min_clusters = 2

# %% [markdown]
# ## Density

# %%
density = np.load("../data/dataset1/8x8_density.npy", allow_pickle=True)
coarse_resolution = 25**2

# Split density into training/testing set and standardize data
density_train, density_test = split_data(density, itr_cutoff = 5)
density_train, _, __ = scale_density(density_train, density_test, density)
density_train = density_train.reshape((605,coarse_resolution))

pca = PCA(n_components = 3, random_state = 0)
pca.fit_transform(density_train)

scree_fig, scree_ax = pca_scree_plot(density_train,
                                     title = "Dataset 1 Cell Density PCA Scree Plot",
                                     max_dim = max_pca_dim,
                                     min_dim = min_pca_dim,
                                     figsize = (7,7))

scree_fig.savefig("../figures/dataset1/density_scree_plot.png", bbox_inches='tight')

elbow_fig, elbow_ax = kmeans_elbow_plot(density_train,
                                        title = "Dataset 1 Cell Density K-means Elbow Plot",
                                        max_clusters = max_clusters,
                                        min_clusters = min_clusters,
                                        figsize = (7,7))
elbow_fig.savefig("../figures/dataset1/density_elbow_plot.png", bbox_inches='tight')

# %% [markdown]
# ## Cell Counts

# %%
cell_counts = np.load("../data/dataset1/cell_counts.npy", allow_pickle = True)

# Split density into training/testing set and standardize data
cell_counts_train, cell_counts_test = split_data(cell_counts, itr_cutoff = 5)
cell_counts_train, _, __ = scale_cell_counts(cell_counts_train, cell_counts_test, cell_counts)
cell_counts_train = cell_counts_train.reshape((605,4*241))

pca = PCA(n_components = 3, random_state = 0)
pca.fit_transform(cell_counts_train)

scree_fig, scree_ax = pca_scree_plot(cell_counts_train,
                                     title = "Dataset 1 Cell Counts PCA Scree Plot",
                                     max_dim = max_pca_dim,
                                     min_dim = min_pca_dim,
                                     figsize = (7,7))
scree_fig.savefig("../figures/dataset1/cell_counts_scree_plot.png", bbox_inches='tight')


elbow_fig, elbow_ax = kmeans_elbow_plot(cell_counts_train,
                                        title = "Dataset 1 Cell Counts K-means Elbow Plot",
                                        max_clusters = max_clusters,
                                        min_clusters = min_clusters,
                                        figsize = (7,7))
elbow_fig.savefig("../figures/dataset1/cell_counts_elbow_plot.png", bbox_inches='tight')

# %% [markdown]
# # **Dataset 2**

# %% [markdown]
# # Density

# %%
density = np.load("../data/dataset2/8x8_density.npy", allow_pickle = True)
density = density.reshape(54450,25,25)
coarse_resolution = (25)**2

# Split density into training/testing set and standardize data
density_train, density_test = split_data(density, itr_cutoff = 5)
density_train, _, __ = scale_density(density_train, density_test, density)
density_train = density_train.reshape((27225,coarse_resolution))

pca = PCA(n_components = 3, random_state = 0)
pca.fit_transform(density_train)

scree_fig, scree_ax = pca_scree_plot(density_train,
                                     title = "Dataset 2 Cell Density PCA Scree Plot",
                                     max_dim = max_pca_dim,
                                     min_dim = min_pca_dim,
                                     figsize = (7,7))
scree_fig.savefig("../figures/dataset2/density_scree_plot.png", bbox_inches='tight')


elbow_fig, elbow_ax = kmeans_elbow_plot(density_train,
                                        title = "Dataset 2 Cell Density K-means Elbow Plot",
                                        max_clusters = max_clusters,
                                        min_clusters = min_clusters,
                                        figsize = (7,7))
elbow_fig.savefig("../figures/dataset2/density_elbow_plot.png", bbox_inches='tight')

# %% [markdown]
# ## Cell Counts

# %%
cell_counts = np.load("../data/dataset2/cell_counts.npy", allow_pickle = True)

# Split density into training/testing set and standardize data
cell_counts_train, cell_counts_test = split_data(cell_counts, itr_cutoff = 5)
cell_counts_train, _, __ = scale_cell_counts(cell_counts_train, cell_counts_test, cell_counts)
cell_counts_train = cell_counts_train.reshape((27225,4*241))

pca = PCA(n_components = 3, random_state = 0)
pca.fit_transform(cell_counts_train)

scree_fig, scree_ax = pca_scree_plot(cell_counts_train,
                                     title = "Dataset 2 Cell Counts PCA Scree Plot",
                                     max_dim = max_pca_dim,
                                     min_dim = min_pca_dim,
                                     figsize = (7,7))
scree_fig.savefig("../figures/dataset2/cell_counts_scree_plot.png", bbox_inches='tight')


elbow_fig, elbow_ax = kmeans_elbow_plot(cell_counts_train,
                                        title = "Dataset 2 Cell Counts K-means Elbow Plot",
                                        max_clusters = max_clusters,
                                        min_clusters = min_clusters,
                                        figsize = (7,7))
elbow_fig.savefig("../figures/dataset2/cell_counts_elbow_plot.png", bbox_inches='tight')

# %%
# %load_ext watermark

# %watermark -n -u -v -iv -w
# Out:
# Last updated: Fri May 23 2025
#
# Python implementation: CPython
# Python version       : 3.12.4
# IPython version      : 8.25.0
#
# yaml      : 6.0.1
# matplotlib: 3.8.4
# numpy     : 1.26.4
# src       : 0.0.0
# sklearn   : 1.4.2
#
# Watermark: 2.5.0
